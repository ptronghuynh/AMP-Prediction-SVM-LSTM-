# %% [markdown]
# # BỘ DỮ LIỆU GENBANK

# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None  # default='warn'
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Concatenate, Reshape, Embedding, GlobalAveragePooling1D, Lambda

# %% [markdown]
# # Nhập và tiền xử lý dữ liệu

# %%
data_amp = pd.read_csv(r'../CSV_20k/genBank_20k/AMP_GenBank_20k.csv')
data_amp = data_amp.sample(10000)

# %%
data_namp = pd.read_csv(r'../CSV_20k/genBank_20k/nAMP_GenBank_20k.csv')
data_namp = data_namp.sample(10000)

# %%
combinated_data = pd.concat([data_amp, data_namp], ignore_index=True)

# %%
data_amp1 = pd.read_csv(r'../CSV_20k/notGenBank_20k/AMP_notGenBank_20k.csv')
data_amp1 = data_amp1.sample(10000)

# %%
data_namp1 = pd.read_csv(r'../CSV_20k/notGenBank_20k/nAMP_notGenBank_20k.csv')
data_namp1 = data_namp1.sample(10000)

# %%
combinated_data1 = pd.concat([data_amp1, data_namp1], ignore_index=True)

# %%
combinated_data = pd.concat([combinated_data, combinated_data1], ignore_index=True)

# %%
data, data_test = train_test_split(combinated_data, test_size=0.3, stratify=combinated_data['Label'], random_state=42, shuffle=True)

# %% [markdown]
# ### Cột "ID" có thể chỉ là một định danh duy nhất cho từng dòng, không mang ý nghĩa đặc biệt trong mô hình.

# %%
data = data.drop(columns=['ID'])
data_test = data_test.drop(columns=['ID'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28000 entries, 14136 to 32782
# Columns: 128 entries, Label to solvent_accessibility_exposed_100%
# dtypes: float64(126), object(2)
# memory usage: 27.6+ MB

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12000 entries, 34342 to 19435
# Columns: 128 entries, Label to solvent_accessibility_exposed_100%
# dtypes: float64(126), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# ### Kiểm tra và xóa số lượng rows trùng lặp

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data_test.duplicated().sum()
# Out:
# 0

# %%
data = data.drop_duplicates()
data_test = data_test.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Kiểm tra xem có cột nào chứa giá trị NaN (khuyết thiếu) hay không.

# %%
null_columns_1 = data.columns[data.isnull().sum() > 0]
print(data[null_columns_1].isnull().sum())

null_columns_2 = data_test.columns[data_test.isnull().sum() > 0]
print(data[null_columns_2].isnull().sum())
# Out:
# Series([], dtype: float64)
# Series([], dtype: float64)

# %% [markdown]
# ### Phân loại các cột theo kiểu dữ liệu
# #### - float_columns: Chứa các cột có kiểu dữ liệu float64 (biến số học).
# #### - object_columns: Chứa các cột có kiểu dữ liệu object (biến dạng chuỗi).

# %%
float_columns = data.select_dtypes(include=['float64']).columns
object_columns = data.select_dtypes(include=['object']).columns

# %% [markdown]
# ### Dữ liệu có 2 cột dạng chuỗi:
# #### - Label: Có thể là nhãn phân loại (ví dụ: Antimicrobial vs Non-Antimicrobial hoặc 1 vs 0).
# #### - Sequence: Chuỗi peptide cần dự đoán.

# %%
object_columns
# Out:
# Index(['Label', 'Sequence'], dtype='object')

# %% [markdown]
# ### Chuyển đổi nhãn (Label) từ chuỗi sang số (0/1):
# #### - Nếu Label == 'nAMP' → gán 0 (Không kháng khuẩn).
# #### - Nếu không phải 'nAMP' → gán 1 (Kháng khuẩn).
# ### Chuyển đổi kiểu dữ liệu thành float để phù hợp với mô hình.

# %%
data.loc[:, 'Label'] = data['Label'].apply(lambda x: 0 if x == 'nAMP' else 1)
data['Label'] = data['Label'].astype(float)

data_test.loc[:, 'Label'] = data_test['Label'].apply(lambda x: 0 if x == 'nAMP' else 1)
data_test['Label'] = data_test['Label'].astype(float)

# data

# %%
label_counts = data['Label'].value_counts()
plt.figure(figsize=(10, 6))
label_counts.plot(kind='bar', color = 'skyblue')
plt.title('Tỉ lệ phân phối chuỗi peptide kháng khuẩn và không kháng khuẩn')
plt.xlabel('Label', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()

# %%
x_test = data_test.drop(columns=['Label'])
y_test = data_test['Label']

X_train = data.drop(columns=['Label'])
y_train = data['Label']

# %% [markdown]
# ### Kiểm tra (mẫu, đặc trưng)

# %%
print(x_test.shape)
print(y_test.shape)

print(X_train.shape)
print(y_train.shape)
# Out:
# (12000, 127)
# (12000,)
# (28000, 127)
# (28000,)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(x_test, y_test, test_size=0.5, stratify=y_test, random_state=42, shuffle=True)

# %% [markdown]
# ### chuỗi sequence dạng chữ, chuyển về chuỗi số

# %%
# sequence_lengths = [len(seq) for seq in  data['Sequence']]  

# # Tính giá trị percentile 95%
# max_length = int(np.percentile(sequence_lengths, 95))  
# print(f"Max length hợp lý dựa trên 95% dữ liệu: {max_length}")

# %% [markdown]
# ### Đệm hoặc cắt ở phía sau
# ###  Lý do chọn 'post':
# #### - Giữ thông tin quan trọng ở đầu chuỗi, vì đầu peptide có thể chứa thông tin quan trọng về tính kháng khuẩn.

# %%
# pip install tensorflow

# %%
max_length = 50

padding_type = 'post' # Đệm thêm số 0
trunc_type = 'post'  # Cắt nếu chuỗi dài

# %%
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(data['Sequence'])
vocab_size = len(tokenizer.word_index) + 1
print("Vocab Size: ",vocab_size)
# Out:
# Vocab Size:  22

# %%
tokenizer.word_index
# Out:
# {'r': 1,
#  'a': 2,
#  'l': 3,
#  'g': 4,
#  'v': 5,
#  'k': 6,
#  's': 7,
#  't': 8,
#  'i': 9,
#  'p': 10,
#  'f': 11,
#  'q': 12,
#  'n': 13,
#  'e': 14,
#  'd': 15,
#  'y': 16,
#  'h': 17,
#  'm': 18,
#  'w': 19,
#  'c': 20,
#  'x': 21}

# %%
train_sequences  = tokenizer.texts_to_sequences(X_train['Sequence'])
train_sequence_array = pad_sequences(train_sequences , maxlen= max_length, padding= padding_type, truncating=trunc_type)

val_sequences = tokenizer.texts_to_sequences(X_val['Sequence'])
val_sequence_array = pad_sequences(val_sequences , maxlen= max_length, padding= padding_type, truncating=trunc_type)

test_sequences = tokenizer.texts_to_sequences(X_test['Sequence'])
test_sequence_array = pad_sequences(test_sequences , maxlen= max_length, padding= padding_type, truncating=trunc_type)

# %%
X_train= X_train.drop(columns=['Sequence'])
X_train['train_sequences'] = train_sequence_array.tolist()

X_val= X_val.drop(columns=['Sequence'])
X_val['val_sequences'] = val_sequence_array.tolist()

X_test= X_test.drop(columns=['Sequence'])
X_test['test_sequences'] = test_sequence_array.tolist()

# %%
X_train.describe()
# Out:
#        hydrophobicity_polar_first  hydrophobicity_polar_20%  \
# count                28000.000000              28000.000000
# mean                     0.213689                  0.288243
# std                      0.176960                  0.185146
# min                      0.000000                  0.000000
# 25%                      0.100000                  0.133333
# 50%                      0.151786                  0.250000
# 75%                      0.300000                  0.400000
# max                      1.000000                  1.000000
#
#        hydrophobicity_polar_40%  hydrophobicity_polar_60%  \
# count              28000.000000              28000.000000
# mean                   0.505293                  0.643252
# std                    0.201797                  0.199858
# min                    0.000000                  0.000000
# 25%                    0.363636                  0.500000
# 50%                    0.500000                  0.692308
# 75%                    0.649351                  0.800000
# max                    1.000000                  1.000000
#
#        hydrophobicity_polar_80%  hydrophobicity_polar_100%  \
# count              28000.000000               28000.000000
# mean                   0.855500                   0.891922
# std                    0.170064                   0.164844
# min                    0.000000                   0.000000
# 25%                    0.800000                   0.833333
# 50%                    0.900000                   1.000000
# 75%                    1.000000                   1.000000
# max                    1.000000                   1.000000
#
#        hydrophobicity_neutral_first  hydrophobicity_neutral_20%  \
# count                  28000.000000                28000.000000
# mean                       0.212615                    0.291177
# std                        0.174683                    0.165757
# min                        0.000000                    0.000000
# 25%                        0.100000                    0.200000
# 50%                        0.153846                    0.266667
# 75%                        0.300000                    0.400000
# max                        1.000000                    1.000000
#
#        hydrophobicity_neutral_40%  hydrophobicity_neutral_60%  ...  \
# count                28000.000000                28000.000000  ...
# mean                     0.461355                    0.627318  ...
# std                      0.176317                    0.179708  ...
# min                      0.000000                    0.000000  ...
# 25%                      0.333333                    0.500000  ...
# 50%                      0.454545                    0.633333  ...
# 75%                      0.600000                    0.750000  ...
# max                      1.000000                    1.000000  ...
#
#        solvent_accessibility_intermediate_40%  \
# count                            28000.000000
# mean                                 0.434646
# std                                  0.237312
# min                                  0.000000
# 25%                                  0.289474
# 50%                                  0.419355
# 75%                                  0.600000
# max                                  1.000000
#
#        solvent_accessibility_intermediate_60%  \
# count                            28000.000000
# mean                                 0.574657
# std                                  0.258723
# min                                  0.000000
# 25%                                  0.400000
# 50%                                  0.600000
# 75%                                  0.777778
# max                                  1.000000
#
#        solvent_accessibility_intermediate_80%  \
# count                            28000.000000
# mean                                 0.692101
# std                                  0.284356
# min                                  0.000000
# 25%                                  0.590909
# 50%                                  0.793103
# 75%                                  0.900000
# max                                  1.000000
#
#        solvent_accessibility_intermediate_100%  \
# count                             28000.000000
# mean                                  0.711958
# std                                   0.292182
# min                                   0.000000
# 25%                                   0.600000
# 50%                                   0.800000
# 75%                                   0.925926
# max                                   1.000000
#
#        solvent_accessibility_exposed_first  solvent_accessibility_exposed_20%  \
# count                         28000.000000                       28000.000000
# mean                              0.213689                           0.288243
# std                               0.176960                           0.185146
# min                               0.000000                           0.000000
# 25%                               0.100000                           0.133333
# 50%                               0.151786                           0.250000
# 75%                               0.300000                           0.400000
# max                               1.000000                           1.000000
#
#        solvent_accessibility_exposed_40%  solvent_accessibility_exposed_60%  \
# count                       28000.000000                       28000.000000
# mean                            0.505293                           0.643252
# std                             0.201797                           0.199858
# min                             0.000000                           0.000000
# 25%                             0.363636                           0.500000
# 50%                             0.500000                           0.692308
# 75%                             0.649351                           0.800000
# max                             1.000000                           1.000000
#
#        solvent_accessibility_exposed_80%  solvent_accessibility_exposed_100%
# count                       28000.000000                        28000.000000
# mean                            0.855500                            0.891922
# std                             0.170064                            0.164844
# min                             0.000000                            0.000000
# 25%                             0.800000                            0.833333
# 50%                             0.900000                            1.000000
# 75%                             1.000000                            1.000000
# max                             1.000000                            1.000000
#
# [8 rows x 126 columns]

# %%
columns_with_max_equal_1 = X_train.columns[X_train.max() == 1]
columns_with_min_equal_0 = X_train.columns[X_train.min() == 0]

# In kết quả
print("Các cột có max == 1:", len(list(columns_with_max_equal_1)))
print("Các cột có min == 0:", len(list(columns_with_min_equal_0)))
# Out:
# Các cột có max == 1: 124
# Các cột có min == 0: 122

# %% [markdown]
# ## Kiểm tra X_train
# #### Tổng có 127 cột. Tách thành 126 + 1 cột mảng

# %%
print(X_train.dtypes.value_counts())
# Out:
# float64    126
# object       1
# Name: count, dtype: int64

# %%
X_train_num = X_train.iloc[:, :126]  # Chọn 126 cột đầu tiên
X_train_text = X_train.iloc[:, -1]   # Chọn cột cuối cùng

# %%
object_cols = X_train.select_dtypes(include=['object']).columns
print("Cột object:", object_cols)
# Out:
# Cột object: Index(['train_sequences'], dtype='object')

# %%
print(X_train_text.head(10))  # Xem 10 dòng đầu
# Out:
# 14136    [8, 5, 16, 9, 15, 1, 2, 14, 8, 1, 0, 0, 0, 0, ...
# 30437    [9, 1, 8, 14, 5, 5, 20, 7, 6, 20, 0, 0, 0, 0, ...
# 810      [1, 6, 1, 3, 1, 15, 3, 13, 3, 4, 16, 4, 3, 9, ...
# 21267    [10, 9, 1, 3, 9, 5, 6, 2, 4, 6, 0, 0, 0, 0, 0,...
# 18040    [5, 14, 8, 8, 3, 12, 1, 6, 8, 9, 7, 13, 3, 6, ...
# 24981    [1, 12, 5, 2, 3, 9, 4, 4, 3, 2, 16, 20, 2, 2, ...
# 30008    [6, 13, 15, 9, 19, 20, 6, 7, 10, 6, 0, 0, 0, 0...
# 21860    [10, 2, 5, 3, 4, 11, 5, 6, 4, 1, 9, 5, 4, 1, 0...
# 12046    [18, 2, 13, 20, 5, 1, 17, 7, 5, 3, 2, 1, 3, 13...
# 24035    [19, 1, 3, 9, 4, 6, 20, 3, 1, 10, 3, 10, 0, 0,...
# Name: train_sequences, dtype: object

# %% [markdown]
# ## Kiểm tra X_val
# #### Tổng có 127 cột. Tách thành 126 + 1 cột mảng

# %%
print(X_val.dtypes.value_counts())
# Out:
# float64    126
# object       1
# Name: count, dtype: int64

# %%
X_val_num = X_val.iloc[:, :126]  # Chọn 126 cột đầu tiên
X_val_text = X_val.iloc[:, -1]   # Chọn cột cuối cùng

# %%
print(X_val_text.head(10))  # Xem 10 dòng đầu
# Out:
# 18096    [6, 4, 7, 10, 6, 14, 5, 6, 15, 6, 0, 0, 0, 0, ...
# 38495    [7, 14, 7, 14, 6, 14, 1, 3, 3, 6, 1, 2, 7, 4, ...
# 31614    [1, 1, 8, 2, 8, 18, 3, 8, 7, 8, 0, 0, 0, 0, 0,...
# 36960    [17, 1, 16, 10, 2, 12, 7, 7, 3, 1, 0, 0, 0, 0,...
# 25563    [2, 11, 9, 3, 16, 6, 16, 1, 11, 10, 6, 12, 13,...
# 4958     [1, 1, 10, 10, 2, 8, 10, 11, 3, 5, 10, 1, 0, 0...
# 33284    [12, 1, 2, 6, 16, 12, 15, 4, 9, 15, 0, 0, 0, 0...
# 5432     [18, 6, 3, 6, 6, 4, 3, 3, 4, 13, 0, 0, 0, 0, 0...
# 29927    [1, 18, 7, 2, 4, 9, 2, 3, 12, 19, 18, 7, 10, 3...
# 22615    [9, 4, 4, 6, 1, 2, 2, 1, 2, 4, 0, 0, 0, 0, 0, ...
# Name: val_sequences, dtype: object

# %% [markdown]
# ## Kiểm tra dữ liệu huấn luyện
# In thử một vài giá trị trong X_train và X_val để kiểm tra xem có giá trị âm hoặc không hợp lệ không

# %%
print(f"X_train_text - NaN: {pd.isna(X_train_text).sum()} / Total: {X_train_text.size}")
print(f"X_val_text - NaN: {pd.isna(X_val_text).sum()} / Total: {X_val_text.size}")
# Out:
# X_train_text - NaN: 0 / Total: 28000
# X_val_text - NaN: 0 / Total: 6000

# %%
# X_train_num = np.array(X_train_num, dtype=np.float32)
# X_val_num = np.array(X_val_num, dtype=np.float32)
X_train_num = X_train_num.to_numpy(dtype=np.float32)
X_val_num = X_val_num.to_numpy(dtype=np.float32)

# %%
# Định nghĩa độ dài cố định cho X_train_text và X_val_text
max_len = max_length  

# Chuyển đổi tất cả thành danh sách cùng kích thước
X_train_text = np.array([seq[:max_len] + [0] * (max_len - len(seq)) if len(seq) < max_len else seq[:max_len] for seq in X_train_text], dtype=np.int32)

X_val_text = np.array([seq[:max_len] + [0] * (max_len - len(seq)) if len(seq) < max_len else seq[:max_len] for seq in X_val_text], dtype=np.int32)

print("X_train_text shape:", X_train_text.shape)
print("X_val_text shape:", X_val_text.shape)
# Out:
# X_train_text shape: (28000, 50)
# X_val_text shape: (6000, 50)

# %% [markdown]
# # MODEL BilLSTM + Attention

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Concatenate, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.layers import GlobalMaxPooling1D, Multiply, Permute
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
# === 1. Reshape dữ liệu đầu vào ===

# Reshape text data to 3D (samples, timesteps, features)
X_train_text_3D = X_train_text.reshape(X_train_text.shape[0], X_train_text.shape[1], 1)
X_train_num_3D = X_train_num.reshape(X_train_num.shape[0], X_train_num.shape[1], 1)
X_val_text_3D = X_val_text.reshape(X_val_text.shape[0], X_val_text.shape[1], 1)
X_val_num_3D = X_val_num.reshape(X_val_num.shape[0], X_val_num.shape[1], 1)

# Convert labels to numpy arrays
y_train_np = np.array(y_train).reshape(-1, 1).astype(np.float32)
y_val_np = np.array(Y_val).reshape(-1, 1).astype(np.float32)

# %%
# ==================== 2. Model with Multi-head Attention ====================

lstm_units = 64
dropout_rate = 0.2
dense_1_units = 64
dense_2_units = 32
num_heads = 4
key_dim = 32  # kích thước khóa (và query)


# Input 1: Text Sequence
sequence_input = Input(shape=(50, 1), name='sequence_input')
# LSTM (return_sequences để Attention xử lý)
x1 = Bidirectional(LSTM(lstm_units, return_sequences=True))(sequence_input)

# Multi-head Attention (self_attention)
attn1 = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(x1, x1)
# bạn cũng có thể thêm residual nếu muốn:
x1 = x1 + attn1

# Global Pool
x1 = GlobalMaxPooling1D()(x1)
x1 = Dropout(dropout_rate)(x1)


# Input 2: Numerical Input
numerical_input = Input(shape=(126, 1), name='numerical_input')
# LSTM
x2 = Bidirectional(LSTM(lstm_units, return_sequences=True))(numerical_input)

# Multi-head Attention
attn2 = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim)(x2, x2)
# residual
x2 = x2 + attn2

# Global Pool
x2 = GlobalMaxPooling1D()(x2)
x2 = Dropout(dropout_rate)(x2)


# Combine both
combined = Concatenate()([x1, x2])

# Dense Layers
x = Dense(dense_1_units, activation='relu')(combined)
x = BatchNormalization()(x)
x = Dropout(dropout_rate)(x)

x = Dense(dense_2_units, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(dropout_rate)(x)

# Output
output = Dense(1, activation='sigmoid')(x)

# %%
# === Tạo model ===
model = Model(inputs=[sequence_input, numerical_input], outputs=output)

# === Compile model ===
optimizer = Adam(learning_rate=0.00001)  # Tăng learning rate nhẹ lên từ 1e-5 → 1e-4
model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ sequence_input (InputLayer)   │ (None, 50, 1)             │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ numerical_input (InputLayer)  │ (None, 126, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional (Bidirectional) │ (None, 50, 128)           │          33,792 │ sequence_input[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional_1               │ (None, 126, 128)          │          33,792 │ numerical_input[0][0]      │
# │ (Bidirectional)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 50, 128)           │          66,048 │ bidirectional[0][0],       │
# │ (MultiHeadAttention)          │                           │                 │ bidirectional[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 126, 128)          │          66,048 │ bidirectional_1[0][0],     │
# │ (MultiHeadAttention)          │                           │                 │ bidirectional_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 50, 128)           │               0 │ bidirectional[0][0],       │
# │                               │                           │                 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 126, 128)          │               0 │ bidirectional_1[0][0],     │
# │                               │                           │                 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling1d          │ (None, 128)               │               0 │ add[0][0]                  │
# │ (GlobalMaxPooling1D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling1d_1        │ (None, 128)               │               0 │ add_1[0][0]                │
# │ (GlobalMaxPooling1D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 128)               │               0 │ global_max_pooling1d[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 128)               │               0 │ global_max_pooling1d_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 256)               │               0 │ dropout_1[0][0],           │
# │                               │                           │                 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 64)                │          16,448 │ concatenate[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 64)                │             256 │ dense[0][0]                │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 64)                │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 32)                │           2,080 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32)                │             128 │ dense_1[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 32)                │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 1)                 │              33 │ dropout_5[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 218,625 (854.00 KB)
#  Trainable params: 218,433 (853.25 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
# === Callbacks ===
weight_path = "{}_weights.best.weights.h5".format('BilLSTM_MultiHeadAttention_Combinate')

checkpoint = ModelCheckpoint(
    filepath=weight_path,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='min'
)

early = EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=149,  
    verbose=1,
    restore_best_weights=True  
)

reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1
)

callbacks_list = [checkpoint, early, reduce]

# %%
# Huấn luyện
history = model.fit(
    [X_train_text_3D, X_train_num_3D],
    y_train_np,
    validation_data=([X_val_text_3D, X_val_num_3D], y_val_np),
    epochs=150,
    batch_size=32,
    callbacks=callbacks_list,
    verbose=1
)
# Out:
# Epoch 1/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5726 - loss: 0.8612
# Epoch 1: val_loss improved from inf to 0.53804, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 78s 80ms/step - accuracy: 0.5727 - loss: 0.8611 - val_accuracy: 0.6727 - val_loss: 0.5380 - learning_rate: 1.0000e-05
# Epoch 2/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6931 - loss: 0.6297
# Epoch 2: val_loss improved from 0.53804 to 0.40603, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 71s 81ms/step - accuracy: 0.6931 - loss: 0.6296 - val_accuracy: 0.8267 - val_loss: 0.4060 - learning_rate: 1.0000e-05
# Epoch 3/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7670 - loss: 0.5121
# Epoch 3: val_loss improved from 0.40603 to 0.34243, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 72s 83ms/step - accuracy: 0.7671 - loss: 0.5121 - val_accuracy: 0.8618 - val_loss: 0.3424 - learning_rate: 1.0000e-05
# Epoch 4/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8143 - loss: 0.4219
# Epoch 4: val_loss improved from 0.34243 to 0.30984, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 74s 84ms/step - accuracy: 0.8143 - loss: 0.4219 - val_accuracy: 0.8742 - val_loss: 0.3098 - learning_rate: 1.0000e-05
# Epoch 5/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8275 - loss: 0.3980
# Epoch 5: val_loss improved from 0.30984 to 0.28757, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 74s 85ms/step - accuracy: 0.8276 - loss: 0.3980 - val_accuracy: 0.8847 - val_loss: 0.2876 - learning_rate: 1.0000e-05
# Epoch 6/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8553 - loss: 0.3489
# Epoch 6: val_loss improved from 0.28757 to 0.26904, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.8553 - loss: 0.3489 - val_accuracy: 0.8905 - val_loss: 0.2690 - learning_rate: 1.0000e-05
# Epoch 7/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8688 - loss: 0.3227
# Epoch 7: val_loss improved from 0.26904 to 0.26127, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 75s 86ms/step - accuracy: 0.8688 - loss: 0.3227 - val_accuracy: 0.8958 - val_loss: 0.2613 - learning_rate: 1.0000e-05
# Epoch 8/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8714 - loss: 0.3100
# Epoch 8: val_loss improved from 0.26127 to 0.24124, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 76s 87ms/step - accuracy: 0.8714 - loss: 0.3100 - val_accuracy: 0.9033 - val_loss: 0.2412 - learning_rate: 1.0000e-05
# Epoch 9/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8833 - loss: 0.2854
# Epoch 9: val_loss improved from 0.24124 to 0.22601, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 77s 88ms/step - accuracy: 0.8833 - loss: 0.2854 - val_accuracy: 0.9092 - val_loss: 0.2260 - learning_rate: 1.0000e-05
# Epoch 10/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8897 - loss: 0.2742
# Epoch 10: val_loss improved from 0.22601 to 0.21069, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 78s 89ms/step - accuracy: 0.8897 - loss: 0.2742 - val_accuracy: 0.9168 - val_loss: 0.2107 - learning_rate: 1.0000e-05
# Epoch 11/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8955 - loss: 0.2563
# Epoch 11: val_loss improved from 0.21069 to 0.19983, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 79s 90ms/step - accuracy: 0.8955 - loss: 0.2563 - val_accuracy: 0.9215 - val_loss: 0.1998 - learning_rate: 1.0000e-05
# Epoch 12/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9014 - loss: 0.2451
# Epoch 12: val_loss improved from 0.19983 to 0.19622, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 79s 91ms/step - accuracy: 0.9014 - loss: 0.2451 - val_accuracy: 0.9213 - val_loss: 0.1962 - learning_rate: 1.0000e-05
# Epoch 13/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9018 - loss: 0.2401
# Epoch 13: val_loss improved from 0.19622 to 0.18586, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 81s 93ms/step - accuracy: 0.9018 - loss: 0.2401 - val_accuracy: 0.9255 - val_loss: 0.1859 - learning_rate: 1.0000e-05
# Epoch 14/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9068 - loss: 0.2301
# Epoch 14: val_loss improved from 0.18586 to 0.18032, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 83s 95ms/step - accuracy: 0.9068 - loss: 0.2301 - val_accuracy: 0.9282 - val_loss: 0.1803 - learning_rate: 1.0000e-05
# Epoch 15/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9142 - loss: 0.2171
# Epoch 15: val_loss improved from 0.18032 to 0.17955, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 84s 96ms/step - accuracy: 0.9142 - loss: 0.2171 - val_accuracy: 0.9293 - val_loss: 0.1796 - learning_rate: 1.0000e-05
# Epoch 16/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9118 - loss: 0.2185
# Epoch 16: val_loss improved from 0.17955 to 0.17043, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 85s 97ms/step - accuracy: 0.9118 - loss: 0.2185 - val_accuracy: 0.9318 - val_loss: 0.1704 - learning_rate: 1.0000e-05
# Epoch 17/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9166 - loss: 0.2099
# Epoch 17: val_loss improved from 0.17043 to 0.16392, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 87s 99ms/step - accuracy: 0.9166 - loss: 0.2099 - val_accuracy: 0.9338 - val_loss: 0.1639 - learning_rate: 1.0000e-05
# Epoch 18/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9188 - loss: 0.2005
# Epoch 18: val_loss improved from 0.16392 to 0.15977, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9188 - loss: 0.2005 - val_accuracy: 0.9347 - val_loss: 0.1598 - learning_rate: 1.0000e-05
# Epoch 19/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9203 - loss: 0.2025
# Epoch 19: val_loss improved from 0.15977 to 0.15715, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 88s 100ms/step - accuracy: 0.9203 - loss: 0.2025 - val_accuracy: 0.9388 - val_loss: 0.1572 - learning_rate: 1.0000e-05
# Epoch 20/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9265 - loss: 0.1904
# Epoch 20: val_loss improved from 0.15715 to 0.15179, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 101ms/step - accuracy: 0.9265 - loss: 0.1904 - val_accuracy: 0.9380 - val_loss: 0.1518 - learning_rate: 1.0000e-05
# Epoch 21/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9265 - loss: 0.1855
# Epoch 21: val_loss did not improve from 0.15179
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 88s 101ms/step - accuracy: 0.9265 - loss: 0.1855 - val_accuracy: 0.9382 - val_loss: 0.1567 - learning_rate: 1.0000e-05
# Epoch 22/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9242 - loss: 0.1927
# Epoch 22: val_loss improved from 0.15179 to 0.15157, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9242 - loss: 0.1927 - val_accuracy: 0.9403 - val_loss: 0.1516 - learning_rate: 1.0000e-05
# Epoch 23/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9272 - loss: 0.1868
# Epoch 23: val_loss improved from 0.15157 to 0.14232, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 88s 101ms/step - accuracy: 0.9272 - loss: 0.1868 - val_accuracy: 0.9430 - val_loss: 0.1423 - learning_rate: 1.0000e-05
# Epoch 24/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9309 - loss: 0.1780
# Epoch 24: val_loss improved from 0.14232 to 0.14126, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 90s 102ms/step - accuracy: 0.9309 - loss: 0.1780 - val_accuracy: 0.9425 - val_loss: 0.1413 - learning_rate: 1.0000e-05
# Epoch 25/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9314 - loss: 0.1771
# Epoch 25: val_loss improved from 0.14126 to 0.13782, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9314 - loss: 0.1771 - val_accuracy: 0.9467 - val_loss: 0.1378 - learning_rate: 1.0000e-05
# Epoch 26/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9338 - loss: 0.1711
# Epoch 26: val_loss did not improve from 0.13782
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9338 - loss: 0.1711 - val_accuracy: 0.9453 - val_loss: 0.1400 - learning_rate: 1.0000e-05
# Epoch 27/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9347 - loss: 0.1715
# Epoch 27: val_loss did not improve from 0.13782
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 90s 102ms/step - accuracy: 0.9347 - loss: 0.1715 - val_accuracy: 0.9452 - val_loss: 0.1426 - learning_rate: 1.0000e-05
# Epoch 28/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9333 - loss: 0.1690
# Epoch 28: val_loss did not improve from 0.13782
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 101ms/step - accuracy: 0.9333 - loss: 0.1690 - val_accuracy: 0.9460 - val_loss: 0.1416 - learning_rate: 1.0000e-05
# Epoch 29/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9355 - loss: 0.1638
# Epoch 29: val_loss improved from 0.13782 to 0.13569, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 90s 103ms/step - accuracy: 0.9355 - loss: 0.1638 - val_accuracy: 0.9490 - val_loss: 0.1357 - learning_rate: 1.0000e-05
# Epoch 30/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9354 - loss: 0.1655
# Epoch 30: val_loss improved from 0.13569 to 0.12785, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9354 - loss: 0.1655 - val_accuracy: 0.9467 - val_loss: 0.1279 - learning_rate: 1.0000e-05
# Epoch 31/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9399 - loss: 0.1540
# Epoch 31: val_loss did not improve from 0.12785
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 90s 102ms/step - accuracy: 0.9399 - loss: 0.1541 - val_accuracy: 0.9495 - val_loss: 0.1317 - learning_rate: 1.0000e-05
# Epoch 32/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9370 - loss: 0.1620
# Epoch 32: val_loss improved from 0.12785 to 0.12397, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 104ms/step - accuracy: 0.9370 - loss: 0.1620 - val_accuracy: 0.9502 - val_loss: 0.1240 - learning_rate: 1.0000e-05
# Epoch 33/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9385 - loss: 0.1620
# Epoch 33: val_loss improved from 0.12397 to 0.12292, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 95s 109ms/step - accuracy: 0.9385 - loss: 0.1620 - val_accuracy: 0.9515 - val_loss: 0.1229 - learning_rate: 1.0000e-05
# Epoch 34/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9386 - loss: 0.1591
# Epoch 34: val_loss improved from 0.12292 to 0.12152, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 101ms/step - accuracy: 0.9386 - loss: 0.1591 - val_accuracy: 0.9507 - val_loss: 0.1215 - learning_rate: 1.0000e-05
# Epoch 35/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9424 - loss: 0.1512
# Epoch 35: val_loss did not improve from 0.12152
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 90s 103ms/step - accuracy: 0.9424 - loss: 0.1512 - val_accuracy: 0.9510 - val_loss: 0.1262 - learning_rate: 1.0000e-05
# Epoch 36/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9368 - loss: 0.1598
# Epoch 36: val_loss did not improve from 0.12152
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 104ms/step - accuracy: 0.9368 - loss: 0.1598 - val_accuracy: 0.9515 - val_loss: 0.1240 - learning_rate: 1.0000e-05
# Epoch 37/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9443 - loss: 0.1497
# Epoch 37: val_loss improved from 0.12152 to 0.11713, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 103ms/step - accuracy: 0.9443 - loss: 0.1497 - val_accuracy: 0.9527 - val_loss: 0.1171 - learning_rate: 1.0000e-05
# Epoch 38/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9451 - loss: 0.1425
# Epoch 38: val_loss improved from 0.11713 to 0.11646, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 103ms/step - accuracy: 0.9451 - loss: 0.1425 - val_accuracy: 0.9543 - val_loss: 0.1165 - learning_rate: 1.0000e-05
# Epoch 39/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9401 - loss: 0.1523
# Epoch 39: val_loss did not improve from 0.11646
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 104ms/step - accuracy: 0.9401 - loss: 0.1523 - val_accuracy: 0.9530 - val_loss: 0.1187 - learning_rate: 1.0000e-05
# Epoch 40/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9439 - loss: 0.1495
# Epoch 40: val_loss improved from 0.11646 to 0.11411, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 105ms/step - accuracy: 0.9439 - loss: 0.1495 - val_accuracy: 0.9555 - val_loss: 0.1141 - learning_rate: 1.0000e-05
# Epoch 41/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9420 - loss: 0.1494
# Epoch 41: val_loss did not improve from 0.11411
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 104ms/step - accuracy: 0.9420 - loss: 0.1494 - val_accuracy: 0.9528 - val_loss: 0.1166 - learning_rate: 1.0000e-05
# Epoch 42/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9437 - loss: 0.1466
# Epoch 42: val_loss did not improve from 0.11411
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 104ms/step - accuracy: 0.9437 - loss: 0.1466 - val_accuracy: 0.9560 - val_loss: 0.1147 - learning_rate: 1.0000e-05
# Epoch 43/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9433 - loss: 0.1499
# Epoch 43: val_loss did not improve from 0.11411
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 92s 106ms/step - accuracy: 0.9433 - loss: 0.1499 - val_accuracy: 0.9542 - val_loss: 0.1152 - learning_rate: 1.0000e-05
# Epoch 44/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9435 - loss: 0.1491
# Epoch 44: val_loss did not improve from 0.11411
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 92s 105ms/step - accuracy: 0.9435 - loss: 0.1491 - val_accuracy: 0.9558 - val_loss: 0.1152 - learning_rate: 1.0000e-05
# Epoch 45/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9466 - loss: 0.1382
# Epoch 45: val_loss improved from 0.11411 to 0.10917, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9466 - loss: 0.1382 - val_accuracy: 0.9575 - val_loss: 0.1092 - learning_rate: 1.0000e-05
# Epoch 46/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9466 - loss: 0.1429
# Epoch 46: val_loss did not improve from 0.10917
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 92s 105ms/step - accuracy: 0.9466 - loss: 0.1429 - val_accuracy: 0.9458 - val_loss: 0.1333 - learning_rate: 1.0000e-05
# Epoch 47/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9451 - loss: 0.1443
# Epoch 47: val_loss improved from 0.10917 to 0.10884, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 92s 105ms/step - accuracy: 0.9451 - loss: 0.1443 - val_accuracy: 0.9583 - val_loss: 0.1088 - learning_rate: 1.0000e-05
# Epoch 48/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9499 - loss: 0.1371
# Epoch 48: val_loss improved from 0.10884 to 0.10717, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 92s 106ms/step - accuracy: 0.9499 - loss: 0.1371 - val_accuracy: 0.9590 - val_loss: 0.1072 - learning_rate: 1.0000e-05
# Epoch 49/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9465 - loss: 0.1374
# Epoch 49: val_loss improved from 0.10717 to 0.10607, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9465 - loss: 0.1374 - val_accuracy: 0.9588 - val_loss: 0.1061 - learning_rate: 1.0000e-05
# Epoch 50/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9483 - loss: 0.1395
# Epoch 50: val_loss did not improve from 0.10607
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9483 - loss: 0.1395 - val_accuracy: 0.9555 - val_loss: 0.1113 - learning_rate: 1.0000e-05
# Epoch 51/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9489 - loss: 0.1359
# Epoch 51: val_loss did not improve from 0.10607
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9489 - loss: 0.1359 - val_accuracy: 0.9603 - val_loss: 0.1066 - learning_rate: 1.0000e-05
# Epoch 52/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9495 - loss: 0.1345
# Epoch 52: val_loss did not improve from 0.10607
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9495 - loss: 0.1345 - val_accuracy: 0.9575 - val_loss: 0.1070 - learning_rate: 1.0000e-05
# Epoch 53/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9504 - loss: 0.1322
# Epoch 53: val_loss improved from 0.10607 to 0.10577, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9504 - loss: 0.1322 - val_accuracy: 0.9590 - val_loss: 0.1058 - learning_rate: 1.0000e-05
# Epoch 54/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9482 - loss: 0.1349
# Epoch 54: val_loss improved from 0.10577 to 0.10359, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9482 - loss: 0.1349 - val_accuracy: 0.9595 - val_loss: 0.1036 - learning_rate: 1.0000e-05
# Epoch 55/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9491 - loss: 0.1333
# Epoch 55: val_loss did not improve from 0.10359
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9491 - loss: 0.1333 - val_accuracy: 0.9595 - val_loss: 0.1040 - learning_rate: 1.0000e-05
# Epoch 56/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9511 - loss: 0.1301
# Epoch 56: val_loss did not improve from 0.10359
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9511 - loss: 0.1301 - val_accuracy: 0.9525 - val_loss: 0.1149 - learning_rate: 1.0000e-05
# Epoch 57/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9529 - loss: 0.1266
# Epoch 57: val_loss improved from 0.10359 to 0.09968, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9529 - loss: 0.1266 - val_accuracy: 0.9615 - val_loss: 0.0997 - learning_rate: 1.0000e-05
# Epoch 58/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9518 - loss: 0.1331
# Epoch 58: val_loss did not improve from 0.09968
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9518 - loss: 0.1331 - val_accuracy: 0.9598 - val_loss: 0.1041 - learning_rate: 1.0000e-05
# Epoch 59/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9507 - loss: 0.1330
# Epoch 59: val_loss did not improve from 0.09968
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 108ms/step - accuracy: 0.9507 - loss: 0.1330 - val_accuracy: 0.9578 - val_loss: 0.1065 - learning_rate: 1.0000e-05
# Epoch 60/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9525 - loss: 0.1294
# Epoch 60: val_loss did not improve from 0.09968
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9525 - loss: 0.1294 - val_accuracy: 0.9608 - val_loss: 0.1039 - learning_rate: 1.0000e-05
# Epoch 61/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9520 - loss: 0.1278
# Epoch 61: val_loss improved from 0.09968 to 0.09912, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9520 - loss: 0.1278 - val_accuracy: 0.9610 - val_loss: 0.0991 - learning_rate: 1.0000e-05
# Epoch 62/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9520 - loss: 0.1250
# Epoch 62: val_loss improved from 0.09912 to 0.09843, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 95s 109ms/step - accuracy: 0.9520 - loss: 0.1250 - val_accuracy: 0.9627 - val_loss: 0.0984 - learning_rate: 1.0000e-05
# Epoch 63/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9510 - loss: 0.1265
# Epoch 63: val_loss did not improve from 0.09843
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9510 - loss: 0.1265 - val_accuracy: 0.9612 - val_loss: 0.0999 - learning_rate: 1.0000e-05
# Epoch 64/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9530 - loss: 0.1231
# Epoch 64: val_loss did not improve from 0.09843
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 107s 122ms/step - accuracy: 0.9530 - loss: 0.1231 - val_accuracy: 0.9627 - val_loss: 0.1008 - learning_rate: 1.0000e-05
# Epoch 65/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9519 - loss: 0.1259
# Epoch 65: val_loss improved from 0.09843 to 0.09774, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 102s 117ms/step - accuracy: 0.9519 - loss: 0.1259 - val_accuracy: 0.9635 - val_loss: 0.0977 - learning_rate: 1.0000e-05
# Epoch 66/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9526 - loss: 0.1306
# Epoch 66: val_loss did not improve from 0.09774
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9526 - loss: 0.1306 - val_accuracy: 0.9528 - val_loss: 0.1185 - learning_rate: 1.0000e-05
# Epoch 67/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9526 - loss: 0.1285
# Epoch 67: val_loss improved from 0.09774 to 0.09585, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 95s 109ms/step - accuracy: 0.9526 - loss: 0.1285 - val_accuracy: 0.9628 - val_loss: 0.0959 - learning_rate: 1.0000e-05
# Epoch 68/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9537 - loss: 0.1233
# Epoch 68: val_loss did not improve from 0.09585
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 104s 119ms/step - accuracy: 0.9537 - loss: 0.1233 - val_accuracy: 0.9587 - val_loss: 0.1050 - learning_rate: 1.0000e-05
# Epoch 69/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9536 - loss: 0.1260
# Epoch 69: val_loss did not improve from 0.09585
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 103s 118ms/step - accuracy: 0.9536 - loss: 0.1260 - val_accuracy: 0.9563 - val_loss: 0.1046 - learning_rate: 1.0000e-05
# Epoch 70/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9544 - loss: 0.1247
# Epoch 70: val_loss did not improve from 0.09585
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 91s 105ms/step - accuracy: 0.9544 - loss: 0.1247 - val_accuracy: 0.9547 - val_loss: 0.1159 - learning_rate: 1.0000e-05
# Epoch 71/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9568 - loss: 0.1163
# Epoch 71: val_loss improved from 0.09585 to 0.09476, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 95s 109ms/step - accuracy: 0.9568 - loss: 0.1163 - val_accuracy: 0.9640 - val_loss: 0.0948 - learning_rate: 1.0000e-05
# Epoch 72/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9530 - loss: 0.1240
# Epoch 72: val_loss did not improve from 0.09476
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 110ms/step - accuracy: 0.9530 - loss: 0.1240 - val_accuracy: 0.9642 - val_loss: 0.0965 - learning_rate: 1.0000e-05
# Epoch 73/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9544 - loss: 0.1236
# Epoch 73: val_loss did not improve from 0.09476
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9544 - loss: 0.1236 - val_accuracy: 0.9568 - val_loss: 0.1037 - learning_rate: 1.0000e-05
# Epoch 74/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9502 - loss: 0.1264
# Epoch 74: val_loss improved from 0.09476 to 0.09119, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 96s 109ms/step - accuracy: 0.9502 - loss: 0.1264 - val_accuracy: 0.9652 - val_loss: 0.0912 - learning_rate: 1.0000e-05
# Epoch 75/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9572 - loss: 0.1181
# Epoch 75: val_loss did not improve from 0.09119
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 95s 109ms/step - accuracy: 0.9572 - loss: 0.1181 - val_accuracy: 0.9665 - val_loss: 0.0921 - learning_rate: 1.0000e-05
# Epoch 76/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9541 - loss: 0.1202
# Epoch 76: val_loss did not improve from 0.09119
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9541 - loss: 0.1202 - val_accuracy: 0.9585 - val_loss: 0.1047 - learning_rate: 1.0000e-05
# Epoch 77/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9527 - loss: 0.1277
# Epoch 77: val_loss did not improve from 0.09119
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9527 - loss: 0.1276 - val_accuracy: 0.9568 - val_loss: 0.1128 - learning_rate: 1.0000e-05
# Epoch 78/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9547 - loss: 0.1190
# Epoch 78: val_loss did not improve from 0.09119
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 88s 100ms/step - accuracy: 0.9547 - loss: 0.1190 - val_accuracy: 0.9655 - val_loss: 0.0913 - learning_rate: 1.0000e-05
# Epoch 79/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9550 - loss: 0.1184
# Epoch 79: val_loss did not improve from 0.09119
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 92s 105ms/step - accuracy: 0.9550 - loss: 0.1184 - val_accuracy: 0.9502 - val_loss: 0.1265 - learning_rate: 1.0000e-05
# Epoch 80/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9547 - loss: 0.1200
# Epoch 80: val_loss improved from 0.09119 to 0.09058, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 102ms/step - accuracy: 0.9547 - loss: 0.1200 - val_accuracy: 0.9668 - val_loss: 0.0906 - learning_rate: 5.0000e-06
# Epoch 81/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9576 - loss: 0.1126
# Epoch 81: val_loss improved from 0.09058 to 0.08926, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9576 - loss: 0.1126 - val_accuracy: 0.9653 - val_loss: 0.0893 - learning_rate: 5.0000e-06
# Epoch 82/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9554 - loss: 0.1195
# Epoch 82: val_loss did not improve from 0.08926
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9554 - loss: 0.1195 - val_accuracy: 0.9630 - val_loss: 0.0916 - learning_rate: 5.0000e-06
# Epoch 83/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9548 - loss: 0.1198
# Epoch 83: val_loss improved from 0.08926 to 0.08916, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 90s 103ms/step - accuracy: 0.9548 - loss: 0.1198 - val_accuracy: 0.9658 - val_loss: 0.0892 - learning_rate: 5.0000e-06
# Epoch 84/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9562 - loss: 0.1130
# Epoch 84: val_loss did not improve from 0.08916
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9562 - loss: 0.1130 - val_accuracy: 0.9645 - val_loss: 0.0929 - learning_rate: 5.0000e-06
# Epoch 85/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9577 - loss: 0.1163
# Epoch 85: val_loss did not improve from 0.08916
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9577 - loss: 0.1163 - val_accuracy: 0.9628 - val_loss: 0.0987 - learning_rate: 5.0000e-06
# Epoch 86/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9554 - loss: 0.1189
# Epoch 86: val_loss did not improve from 0.08916
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 88s 100ms/step - accuracy: 0.9554 - loss: 0.1189 - val_accuracy: 0.9638 - val_loss: 0.0902 - learning_rate: 5.0000e-06
# Epoch 87/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9591 - loss: 0.1135
# Epoch 87: val_loss improved from 0.08916 to 0.08811, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 90s 103ms/step - accuracy: 0.9591 - loss: 0.1135 - val_accuracy: 0.9687 - val_loss: 0.0881 - learning_rate: 2.5000e-06
# Epoch 88/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9572 - loss: 0.1151
# Epoch 88: val_loss improved from 0.08811 to 0.08701, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 113ms/step - accuracy: 0.9572 - loss: 0.1151 - val_accuracy: 0.9677 - val_loss: 0.0870 - learning_rate: 2.5000e-06
# Epoch 89/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9559 - loss: 0.1174
# Epoch 89: val_loss improved from 0.08701 to 0.08679, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9559 - loss: 0.1174 - val_accuracy: 0.9683 - val_loss: 0.0868 - learning_rate: 2.5000e-06
# Epoch 90/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9583 - loss: 0.1077
# Epoch 90: val_loss did not improve from 0.08679
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 89s 101ms/step - accuracy: 0.9583 - loss: 0.1077 - val_accuracy: 0.9683 - val_loss: 0.0876 - learning_rate: 2.5000e-06
# Epoch 91/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9588 - loss: 0.1122
# Epoch 91: val_loss improved from 0.08679 to 0.08633, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 94s 107ms/step - accuracy: 0.9588 - loss: 0.1122 - val_accuracy: 0.9665 - val_loss: 0.0863 - learning_rate: 2.5000e-06
# Epoch 92/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9581 - loss: 0.1101
# Epoch 92: val_loss did not improve from 0.08633
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9581 - loss: 0.1101 - val_accuracy: 0.9680 - val_loss: 0.0868 - learning_rate: 2.5000e-06
# Epoch 93/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9554 - loss: 0.1169
# Epoch 93: val_loss did not improve from 0.08633
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 116ms/step - accuracy: 0.9554 - loss: 0.1169 - val_accuracy: 0.9688 - val_loss: 0.0867 - learning_rate: 2.5000e-06
# Epoch 94/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9564 - loss: 0.1173
# Epoch 94: val_loss did not improve from 0.08633
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 102s 117ms/step - accuracy: 0.9564 - loss: 0.1173 - val_accuracy: 0.9665 - val_loss: 0.0875 - learning_rate: 2.5000e-06
# Epoch 95/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9565 - loss: 0.1187
# Epoch 95: val_loss did not improve from 0.08633
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9565 - loss: 0.1187 - val_accuracy: 0.9678 - val_loss: 0.0872 - learning_rate: 2.5000e-06
# Epoch 96/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9583 - loss: 0.1120
# Epoch 96: val_loss did not improve from 0.08633
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 115ms/step - accuracy: 0.9583 - loss: 0.1120 - val_accuracy: 0.9690 - val_loss: 0.0864 - learning_rate: 2.5000e-06
# Epoch 97/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9563 - loss: 0.1149
# Epoch 97: val_loss did not improve from 0.08633
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 120s 137ms/step - accuracy: 0.9563 - loss: 0.1149 - val_accuracy: 0.9693 - val_loss: 0.0867 - learning_rate: 1.2500e-06
# Epoch 98/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9604 - loss: 0.1073
# Epoch 98: val_loss did not improve from 0.08633
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 107s 122ms/step - accuracy: 0.9604 - loss: 0.1073 - val_accuracy: 0.9692 - val_loss: 0.0864 - learning_rate: 1.2500e-06
# Epoch 99/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9589 - loss: 0.1097
# Epoch 99: val_loss did not improve from 0.08633
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9589 - loss: 0.1097 - val_accuracy: 0.9665 - val_loss: 0.0865 - learning_rate: 1.2500e-06
# Epoch 100/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9582 - loss: 0.1127
# Epoch 100: val_loss improved from 0.08633 to 0.08618, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 110ms/step - accuracy: 0.9582 - loss: 0.1127 - val_accuracy: 0.9663 - val_loss: 0.0862 - learning_rate: 1.2500e-06
# Epoch 101/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9575 - loss: 0.1134
# Epoch 101: val_loss improved from 0.08618 to 0.08569, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9575 - loss: 0.1134 - val_accuracy: 0.9670 - val_loss: 0.0857 - learning_rate: 1.2500e-06
# Epoch 102/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9569 - loss: 0.1121
# Epoch 102: val_loss did not improve from 0.08569
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 96s 110ms/step - accuracy: 0.9569 - loss: 0.1121 - val_accuracy: 0.9692 - val_loss: 0.0864 - learning_rate: 1.2500e-06
# Epoch 103/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9599 - loss: 0.1090
# Epoch 103: val_loss did not improve from 0.08569
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9599 - loss: 0.1090 - val_accuracy: 0.9670 - val_loss: 0.0860 - learning_rate: 1.2500e-06
# Epoch 104/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9592 - loss: 0.1143
# Epoch 104: val_loss improved from 0.08569 to 0.08558, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 96s 110ms/step - accuracy: 0.9592 - loss: 0.1143 - val_accuracy: 0.9673 - val_loss: 0.0856 - learning_rate: 1.2500e-06
# Epoch 105/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9574 - loss: 0.1152
# Epoch 105: val_loss did not improve from 0.08558
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9574 - loss: 0.1152 - val_accuracy: 0.9675 - val_loss: 0.0856 - learning_rate: 1.2500e-06
# Epoch 106/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9583 - loss: 0.1096
# Epoch 106: val_loss improved from 0.08558 to 0.08544, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9583 - loss: 0.1096 - val_accuracy: 0.9682 - val_loss: 0.0854 - learning_rate: 1.2500e-06
# Epoch 107/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9574 - loss: 0.1098
# Epoch 107: val_loss did not improve from 0.08544
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9574 - loss: 0.1098 - val_accuracy: 0.9683 - val_loss: 0.0855 - learning_rate: 1.2500e-06
# Epoch 108/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9585 - loss: 0.1128
# Epoch 108: val_loss improved from 0.08544 to 0.08530, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 102s 117ms/step - accuracy: 0.9585 - loss: 0.1128 - val_accuracy: 0.9663 - val_loss: 0.0853 - learning_rate: 1.2500e-06
# Epoch 109/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9571 - loss: 0.1124
# Epoch 109: val_loss did not improve from 0.08530
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 97s 111ms/step - accuracy: 0.9571 - loss: 0.1124 - val_accuracy: 0.9650 - val_loss: 0.0870 - learning_rate: 1.2500e-06
# Epoch 110/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9577 - loss: 0.1148
# Epoch 110: val_loss improved from 0.08530 to 0.08511, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 111ms/step - accuracy: 0.9577 - loss: 0.1148 - val_accuracy: 0.9677 - val_loss: 0.0851 - learning_rate: 1.2500e-06
# Epoch 111/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9577 - loss: 0.1155
# Epoch 111: val_loss did not improve from 0.08511
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9577 - loss: 0.1155 - val_accuracy: 0.9693 - val_loss: 0.0853 - learning_rate: 1.2500e-06
# Epoch 112/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9596 - loss: 0.1109
# Epoch 112: val_loss did not improve from 0.08511
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9596 - loss: 0.1109 - val_accuracy: 0.9657 - val_loss: 0.0863 - learning_rate: 1.2500e-06
# Epoch 113/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9607 - loss: 0.1053
# Epoch 113: val_loss improved from 0.08511 to 0.08495, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9607 - loss: 0.1053 - val_accuracy: 0.9682 - val_loss: 0.0850 - learning_rate: 1.2500e-06
# Epoch 114/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9582 - loss: 0.1120
# Epoch 114: val_loss did not improve from 0.08495
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9582 - loss: 0.1120 - val_accuracy: 0.9695 - val_loss: 0.0860 - learning_rate: 1.2500e-06
# Epoch 115/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9571 - loss: 0.1142
# Epoch 115: val_loss did not improve from 0.08495
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9571 - loss: 0.1142 - val_accuracy: 0.9675 - val_loss: 0.0851 - learning_rate: 1.2500e-06
# Epoch 116/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9589 - loss: 0.1072
# Epoch 116: val_loss did not improve from 0.08495
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9589 - loss: 0.1072 - val_accuracy: 0.9665 - val_loss: 0.0856 - learning_rate: 1.2500e-06
# Epoch 117/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9584 - loss: 0.1106
# Epoch 117: val_loss did not improve from 0.08495
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9584 - loss: 0.1106 - val_accuracy: 0.9673 - val_loss: 0.0850 - learning_rate: 1.2500e-06
# Epoch 118/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9590 - loss: 0.1083
# Epoch 118: val_loss did not improve from 0.08495
#
# Epoch 118: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9590 - loss: 0.1083 - val_accuracy: 0.9688 - val_loss: 0.0860 - learning_rate: 1.2500e-06
# Epoch 119/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9613 - loss: 0.1076
# Epoch 119: val_loss improved from 0.08495 to 0.08493, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9613 - loss: 0.1076 - val_accuracy: 0.9673 - val_loss: 0.0849 - learning_rate: 6.2500e-07
# Epoch 120/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9606 - loss: 0.1096
# Epoch 120: val_loss did not improve from 0.08493
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 98s 112ms/step - accuracy: 0.9606 - loss: 0.1096 - val_accuracy: 0.9690 - val_loss: 0.0851 - learning_rate: 6.2500e-07
# Epoch 121/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9588 - loss: 0.1132
# Epoch 121: val_loss improved from 0.08493 to 0.08476, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9588 - loss: 0.1132 - val_accuracy: 0.9673 - val_loss: 0.0848 - learning_rate: 6.2500e-07
# Epoch 122/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9589 - loss: 0.1101
# Epoch 122: val_loss did not improve from 0.08476
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9589 - loss: 0.1101 - val_accuracy: 0.9692 - val_loss: 0.0849 - learning_rate: 6.2500e-07
# Epoch 123/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9579 - loss: 0.1116
# Epoch 123: val_loss did not improve from 0.08476
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9579 - loss: 0.1116 - val_accuracy: 0.9677 - val_loss: 0.0848 - learning_rate: 6.2500e-07
# Epoch 124/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9588 - loss: 0.1103
# Epoch 124: val_loss improved from 0.08476 to 0.08464, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 115ms/step - accuracy: 0.9588 - loss: 0.1103 - val_accuracy: 0.9685 - val_loss: 0.0846 - learning_rate: 6.2500e-07
# Epoch 125/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9576 - loss: 0.1149
# Epoch 125: val_loss did not improve from 0.08464
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 99s 113ms/step - accuracy: 0.9576 - loss: 0.1149 - val_accuracy: 0.9695 - val_loss: 0.0848 - learning_rate: 6.2500e-07
# Epoch 126/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9610 - loss: 0.1048
# Epoch 126: val_loss did not improve from 0.08464
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9610 - loss: 0.1048 - val_accuracy: 0.9692 - val_loss: 0.0849 - learning_rate: 6.2500e-07
# Epoch 127/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9577 - loss: 0.1137
# Epoch 127: val_loss improved from 0.08464 to 0.08457, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9577 - loss: 0.1137 - val_accuracy: 0.9683 - val_loss: 0.0846 - learning_rate: 6.2500e-07
# Epoch 128/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9582 - loss: 0.1147
# Epoch 128: val_loss improved from 0.08457 to 0.08457, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 115ms/step - accuracy: 0.9582 - loss: 0.1147 - val_accuracy: 0.9688 - val_loss: 0.0846 - learning_rate: 6.2500e-07
# Epoch 129/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9571 - loss: 0.1127
# Epoch 129: val_loss did not improve from 0.08457
#
# Epoch 129: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 115ms/step - accuracy: 0.9571 - loss: 0.1127 - val_accuracy: 0.9688 - val_loss: 0.0847 - learning_rate: 6.2500e-07
# Epoch 130/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9593 - loss: 0.1105
# Epoch 130: val_loss improved from 0.08457 to 0.08447, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 115ms/step - accuracy: 0.9593 - loss: 0.1105 - val_accuracy: 0.9680 - val_loss: 0.0845 - learning_rate: 3.1250e-07
# Epoch 131/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9571 - loss: 0.1100
# Epoch 131: val_loss did not improve from 0.08447
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9571 - loss: 0.1100 - val_accuracy: 0.9687 - val_loss: 0.0845 - learning_rate: 3.1250e-07
# Epoch 132/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9587 - loss: 0.1142
# Epoch 132: val_loss did not improve from 0.08447
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9587 - loss: 0.1142 - val_accuracy: 0.9690 - val_loss: 0.0849 - learning_rate: 3.1250e-07
# Epoch 133/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9597 - loss: 0.1102
# Epoch 133: val_loss did not improve from 0.08447
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 116ms/step - accuracy: 0.9597 - loss: 0.1102 - val_accuracy: 0.9682 - val_loss: 0.0845 - learning_rate: 3.1250e-07
# Epoch 134/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9597 - loss: 0.1120
# Epoch 134: val_loss improved from 0.08447 to 0.08444, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9597 - loss: 0.1120 - val_accuracy: 0.9682 - val_loss: 0.0844 - learning_rate: 3.1250e-07
# Epoch 135/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9596 - loss: 0.1142
# Epoch 135: val_loss improved from 0.08444 to 0.08436, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9596 - loss: 0.1141 - val_accuracy: 0.9680 - val_loss: 0.0844 - learning_rate: 3.1250e-07
# Epoch 136/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9585 - loss: 0.1100
# Epoch 136: val_loss improved from 0.08436 to 0.08434, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9585 - loss: 0.1100 - val_accuracy: 0.9678 - val_loss: 0.0843 - learning_rate: 3.1250e-07
# Epoch 137/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9586 - loss: 0.1128
# Epoch 137: val_loss did not improve from 0.08434
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 115ms/step - accuracy: 0.9586 - loss: 0.1128 - val_accuracy: 0.9678 - val_loss: 0.0844 - learning_rate: 3.1250e-07
# Epoch 138/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9573 - loss: 0.1110
# Epoch 138: val_loss improved from 0.08434 to 0.08433, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9573 - loss: 0.1110 - val_accuracy: 0.9678 - val_loss: 0.0843 - learning_rate: 3.1250e-07
# Epoch 139/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9606 - loss: 0.1066
# Epoch 139: val_loss did not improve from 0.08433
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9606 - loss: 0.1066 - val_accuracy: 0.9687 - val_loss: 0.0843 - learning_rate: 3.1250e-07
# Epoch 140/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9589 - loss: 0.1149
# Epoch 140: val_loss improved from 0.08433 to 0.08425, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 115ms/step - accuracy: 0.9589 - loss: 0.1149 - val_accuracy: 0.9687 - val_loss: 0.0843 - learning_rate: 3.1250e-07
# Epoch 141/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9577 - loss: 0.1121
# Epoch 141: val_loss did not improve from 0.08425
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9577 - loss: 0.1121 - val_accuracy: 0.9688 - val_loss: 0.0845 - learning_rate: 3.1250e-07
# Epoch 142/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9595 - loss: 0.1093
# Epoch 142: val_loss did not improve from 0.08425
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9595 - loss: 0.1093 - val_accuracy: 0.9677 - val_loss: 0.0846 - learning_rate: 3.1250e-07
# Epoch 143/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9584 - loss: 0.1149
# Epoch 143: val_loss did not improve from 0.08425
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9584 - loss: 0.1149 - val_accuracy: 0.9695 - val_loss: 0.0847 - learning_rate: 3.1250e-07
# Epoch 144/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9569 - loss: 0.1113
# Epoch 144: val_loss improved from 0.08425 to 0.08419, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 105s 119ms/step - accuracy: 0.9569 - loss: 0.1113 - val_accuracy: 0.9690 - val_loss: 0.0842 - learning_rate: 3.1250e-07
# Epoch 145/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9593 - loss: 0.1085
# Epoch 145: val_loss improved from 0.08419 to 0.08407, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 115ms/step - accuracy: 0.9593 - loss: 0.1085 - val_accuracy: 0.9680 - val_loss: 0.0841 - learning_rate: 3.1250e-07
# Epoch 146/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9576 - loss: 0.1102
# Epoch 146: val_loss improved from 0.08407 to 0.08405, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9576 - loss: 0.1102 - val_accuracy: 0.9678 - val_loss: 0.0841 - learning_rate: 3.1250e-07
# Epoch 147/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9567 - loss: 0.1165
# Epoch 147: val_loss did not improve from 0.08405
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9567 - loss: 0.1165 - val_accuracy: 0.9683 - val_loss: 0.0841 - learning_rate: 3.1250e-07
# Epoch 148/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9575 - loss: 0.1149
# Epoch 148: val_loss improved from 0.08405 to 0.08404, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 101s 115ms/step - accuracy: 0.9575 - loss: 0.1149 - val_accuracy: 0.9690 - val_loss: 0.0840 - learning_rate: 3.1250e-07
# Epoch 149/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9594 - loss: 0.1065
# Epoch 149: val_loss did not improve from 0.08404
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9594 - loss: 0.1065 - val_accuracy: 0.9687 - val_loss: 0.0841 - learning_rate: 3.1250e-07
# Epoch 150/150
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9591 - loss: 0.1088
# Epoch 150: val_loss improved from 0.08404 to 0.08403, saving model to BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5
#
# Epoch 150: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 100s 114ms/step - accuracy: 0.9591 - loss: 0.1088 - val_accuracy: 0.9677 - val_loss: 0.0840 - learning_rate: 3.1250e-07
# Restoring model weights from the end of the best epoch: 150.

# %%
def plot_history_accuracy(history):
    plt.plot(history.history["accuracy"], label="Training Accuracy")
    plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
    plt.legend()
    plt.grid()
    plt.show()

plot_history_accuracy(history=history)

# %%
def plot_history_loss(history):
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.legend()
    plt.grid()
    plt.show()

plot_history_loss(history=history)

# %%
X_test_num = X_test.iloc[:, :126]  # Chọn 126 cột đầu tiên
X_test_text = X_test.iloc[:, -1]   # Chọn cột cuối cùng

# X_test_num = np.array(X_test_num, dtype=np.float32)
X_test_num = X_test_num.to_numpy(dtype=np.float32)
X_test_num_np = X_test_num.reshape(-1, 126, 1).astype(np.float32)

# %%
# Định nghĩa độ dài cố định cho X_train_text và X_val_text
max_len = max_length

# Chuyển đổi tất cả thành danh sách cùng kích thước
# X_test_text = np.array([seq[:max_len] + [0] * (max_len - len(seq)) if len(seq) < max_len else seq[:max_len] for seq in X_test_text], dtype=np.int32)
X_test_text = test_sequence_array
X_test_seq = X_test_text.reshape(-1, max_len, 1)

print("X_train_text shape:", X_test_seq.shape)
# Out:
# X_train_text shape: (6000, 50, 1)

# %%
predictions = model.predict([X_test_seq, X_test_num_np], verbose=True)
predictions = (predictions >= 0.5).astype(int)
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix

print(classification_report(Y_test, predictions, target_names=['nAMP (Class 0)', 'AMP (Class 1)']))
# Out:
#                 precision    recall  f1-score   support
#
# nAMP (Class 0)       0.97      0.97      0.97      3000
#  AMP (Class 1)       0.97      0.97      0.97      3000
#
#       accuracy                           0.97      6000
#      macro avg       0.97      0.97      0.97      6000
#   weighted avg       0.97      0.97      0.97      6000

# %%
cm = confusion_matrix(Y_test, predictions)
cm = pd.DataFrame(cm, index=['nAMP', 'AMP'], columns=['nAMP', 'AMP'])

# %%
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.heatmap(cm, cmap="Blues", linecolor='black', linewidth=1, annot=True, fmt='d', xticklabels=cm.columns, yticklabels=cm.index)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # EXPLAINABLE AI

# %%
model.load_weights('BilLSTM_MultiHeadAttention_Combinate_weights.best.weights.h5')

# %%
def compute_saliency_sequence_branch(model, input_seq_tensor, input_num_tensor):
    input_seq_tensor = tf.convert_to_tensor(input_seq_tensor)
    input_seq_tensor = tf.cast(input_seq_tensor, tf.float32)
    input_num_tensor = tf.convert_to_tensor(input_num_tensor)
    input_num_tensor = tf.cast(input_num_tensor, tf.float32)

    with tf.GradientTape() as tape:
        tape.watch(input_seq_tensor)

        prediction = model([input_seq_tensor, input_num_tensor], training=False)

    grads = tape.gradient(prediction, input_seq_tensor)

    if grads is None:
        raise ValueError("Gradient could not be computed. Ensure input is used in computation graph.")
    
    saliency = tf.abs(grads).numpy()
    return saliency

# %%
# Giả sử bạn muốn giải thích cho sample đầu tiên
x_seq = X_val_text_3D[1:2]  # (1, 50, 1)
x_num = X_val_num_3D[1:2]   # (1, 126, 1)

# Tính saliency
saliency_map = compute_saliency_sequence_branch(model, x_seq, x_num)  # (1, 50, 1)

# Tính độ quan trọng tại từng vị trí (mean theo chiều cuối)
mean_saliency = np.mean(saliency_map[0], axis=-1)  # (50,)

# %%
# 1. Tạo ánh xạ ngược từ số về ký tự
index_to_char = {v: k.upper() for k, v in tokenizer.word_index.items()}
index_to_char[0] = 'PAD'

# 2. Flatten và chuyển token
token_indices = x_seq[0].flatten().astype(int)
feature_names = [index_to_char.get(idx, '?') for idx in token_indices]

# 3. Lọc bỏ PAD khỏi cả feature_names và mean_saliency
filtered_feature_names = []
filtered_saliency = []

for name, score in zip(feature_names, mean_saliency):
    if name != 'PAD':
        filtered_feature_names.append(name)
        filtered_saliency.append(score)

# %%
plt.figure(figsize=(12, 6))
bars = plt.bar(range(len(filtered_saliency)), filtered_saliency, color='skyblue')
plt.xticks(range(len(filtered_saliency)), filtered_feature_names, rotation=90)
plt.xlabel("Amino Acid Sequence (Sequence Position)")
plt.ylabel("Saliency Score")
plt.title("Feature Importance per Amino Acid Position")
plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.subplots_adjust(bottom=0.25)
plt.show()
