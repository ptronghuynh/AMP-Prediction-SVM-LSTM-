# %% [markdown]
# # External Validation Summary
#
# This notebook summarizes the external validation outputs reported in the manuscript. The executed dataset-specific notebooks are stored in `notebooks/external/`.

# %%
import pandas as pd

metrics = pd.read_csv('../results/external_validation_metrics.csv')
metrics

# %% [markdown]
# Dataset-specific notebooks:
#
# - `external/lstm_AMPDiscover.ipynb`
# - `external/lstm_DDBL.ipynb`
# - `external/lstm_EMBL.ipynb`
# - `external/lstm_RefSeq.ipynb`
# - `external/lstm_SSFGM.ipynb`
# - `external/lstm_XU.ipynb`
