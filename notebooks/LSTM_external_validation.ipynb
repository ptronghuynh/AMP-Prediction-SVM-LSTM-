# %% [markdown]
# # LSTM_external_validation
#
# External-validation summary notebook for the LSTM-combined pipeline on AMPDiscover, DDBL, EMBL, RefSeq, SSFGM, and XU. External validation is reported for LSTM-combined only.

# %%
from pathlib import Path
import csv
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'scripts'))
from make_result_tables import main as make_result_tables
make_result_tables()

# %%
table6 = ROOT / 'results' / 'table6_lstm_external_validation.csv'
with table6.open(newline='', encoding='utf-8') as handle:
    for row in csv.DictReader(handle):
        print(row['dataset'], row['test_n'], row['accuracy'], row['accuracy_ci_low'], row['accuracy_ci_high'], row['auc_roc'])

# %%
figure = ROOT / 'figures' / 'Fig6_external_accuracy_CI.png'
print('Figure file:', figure)
